# %%
# requests

import requests

# %%
# criando um re

url = 'https://quotes.toscrape.com/'

# criando um request e retornando o codigo de retorno
r = requests.get(url)
status = r.status_code
print(status)
# Out:
# 200

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="change,deep-thoughts,thinking,world" /    > \n            \n            <a class="tag" href="/tag/change/page/1/">change</a>\n            \n            <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>\n            \n            <a class="tag" href="/tag/thinking/page/1/">thinking</a>\n            \n            <a class="tag" href="/tag/world/page/1/">world</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>\n        <span>by <small class="author" itemprop="author">J.K. Rowling</small>\n        <a href="/author/J-K-Rowling">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="abilities,choices" /    > \n            \n            <a class="tag" href="/tag/abilities/page/1/">abilities</a>\n            \n            <a class="tag" href="/tag/choices/page/1/">choices</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="inspirational,life,live,miracle,miracles" /    > \n            \n            <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>\n            \n            <a class="tag" href="/tag/life/page/1/">life</a>\n            \n            <a class="tag" href="/tag/live/page/1/">live</a>\n            \n            <a class="tag" href="/tag/miracle/page/1/">miracle</a>\n            \n            <a class="tag" href="/tag/miracles/page/1/">miracles</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>\n        <span>by <small class="author" itemprop="author">Jane Austen</small>\n        <a href="/author/Jane-Austen">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="aliteracy,books,classic,humor" /    > \n            \n            <a class="tag" href= ...

# %%
# HTTP GET METHOD

r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '29788738478',
#   'type': 'PushEvent',
#   'actor': {'id': 130859839,
#    'login': 'TheKaVu',
#    'display_login': 'TheKaVu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TheKaVu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/130859839?'},
#   'repo': {'id': 628368984,
#    'name': 'TheKaVu/GameAPI',
#    'url': 'https://api.github.com/repos/TheKaVu/GameAPI'},
#   'payload': {'repository_id': 628368984,
#    'push_id': 13999731722,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/refactor/master',
#    'head': '1f32fd8add5febe57c7f08df125b129c0ba15805',
#    'before': '274f65b2e31bb6a556dea30560467f7eadafde60',
#    'commits': [{'sha': '1f32fd8add5febe57c7f08df125b129c0ba15805',
#      'author': {'email': 'k.wieczaszek@gmail.com', 'name': 'TheKaVu'},
#      'message': 'Renamed GameType.java to Game.java (#53)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TheKaVu/GameAPI/commits/1f32fd8add5febe57c7f08df125b129c0ba15805'}]},
#   'public': True,
#   'created_at': '2023-06-15T18:21:22Z'},
#  {'id': '29788738851',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 123596332,
#    'login': 'cyduckk',
#    'display_login': 'cyduckk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cyduckk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/123596332?'},
#   'repo': {'id': 653321687,
#    'name': 'Cat-Snake-Industries/BinaryBond',
#    'url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond'},
#   'payload': {'action': 'created',
#    'review': {'id': 1482163504,
#     'node_id': 'PRR_kwDOJvDl185YWAUw',
#     'user': {'login': 'cyduckk',
#      'id': 123596332,
#      'node_id': 'U_kgDOB13uLA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/123596332?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cyduckk',
#      'html_url': 'https://github.com/cyduckk',
#      'followers_url': 'https://api.github.com/users/cyduckk/followers',
#      'following_url': 'https://api.github.com/users/cyduckk/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cyduckk/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cyduckk/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cyduckk/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cyduckk/orgs',
#      'repos_url': 'https://api.github.com/users/cyduckk/repos',
#      'events_url': 'https://api.github.com/users/cyduckk/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cyduckk/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'looks good!',
#     'commit_id': '591c4668b002ed536a9fc545f6099ea9bdd065c2',
#     'submitted_at': '2023-06-15T18:21:23Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/Cat-Snake-Industries/BinaryBond/pull/4#pullrequestreview-1482163504',
#     'pull_request_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls/4',
#     'author_association': 'NONE',
#     '_links': {'html': {'href': 'https://github.com/Cat-Snake-Industries/BinaryBond/pull/4#pullrequestreview-1482163504'},
#      'pull_request': {'href': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls/4'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls/4',
#     'id': 1394576241,
#     'node_id': 'PR_kwDOJvDl185TH4tx',
#     'html_url': 'https://github.com/Cat-Snake-Industries/BinaryBond/pull/4',
#     'diff_url': 'https://github.com/Cat-Snake-Industries/BinaryBond/pull/4.diff',
#     'patch_url': 'https://github.com/Cat-Snake-Industries/BinaryBond/pull/4.patch',
#     'issue_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/issues/4',
#     'number': 4,
#     'state': 'open',
#     'locked': False,
#     'title': 'Tom/profilepic',
#     'user': {'login': 'cronullarc',
#      'id': 125517864,
#      'node_id': 'U_kgDOB3tAKA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/125517864?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cronullarc',
#      'html_url': 'https://github.com/cronullarc',
#      'followers_url': 'https://api.github.com/users/cronullarc/followers',
#      'following_url': 'https://api.github.com/users/cronullarc/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cronullarc/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cronullarc/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cronullarc/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cronullarc/orgs',
#      'repos_url': 'https://api.github.com/users/cronullarc/repos',
#      'events_url': 'https://api.github.com/users/cronullarc/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cronullarc/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2023-06-15T18:21:03Z',
#     'updated_at': '2023-06-15T18:21:23Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '264964913b0ffc1b8208f42336a119c1ab34655e',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls/4/commits',
#     'review_comments_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls/4/comments',
#     'review_comment_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/issues/4/comments',
#     'statuses_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/statuses/591c4668b002ed536a9fc545f6099ea9bdd065c2',
#     'head': {'label': 'Cat-Snake-Industries:tom/profilepic',
#      'ref': 'tom/profilepic',
#      'sha': '591c4668b002ed536a9fc545f6099ea9bdd065c2',
#      'user': {'login': 'Cat-Snake-Industries',
#       'id': 136504448,
#       'node_id': 'O_kgDOCCLkgA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/136504448?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Cat-Snake-Industries',
#       'html_url': 'https://github.com/Cat-Snake-Industries',
#       'followers_url': 'https://api.github.com/users/Cat-Snake-Industries/followers',
#       'following_url': 'https://api.github.com/users/Cat-Snake-Industries/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Cat-Snake-Industries/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Cat-Snake-Industries/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Cat-Snake-Industries/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Cat-Snake-Industries/orgs',
#       'repos_url': 'https://api.github.com/users/Cat-Snake-Industries/repos',
#       'events_url': 'https://api.github.com/users/Cat-Snake-Industries/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Cat-Snake-Industries/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 653321687,
#       'node_id': 'R_kgDOJvDl1w',
#       'name': 'BinaryBond',
#       'full_name': 'Cat-Snake-Industries/BinaryBond',
#       'private': False,
#       'owner': {'login': 'Cat-Snake-Industries',
#        'id': 136504448,
#        'node_id': 'O_kgDOCCLkgA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/136504448?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Cat-Snake-Industries',
#        'html_url': 'https://github.com/Cat-Snake-Industries',
#        'followers_url': 'https://api.github.com/users/Cat-Snake-Industries/followers',
#        'following_url': 'https://api.github.com/users/Cat-Snake-Industries/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Cat-Snake-Industries/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Cat-Snake-Industries/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Cat-Snake-Industries/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Cat-Snake-Industries/orgs',
#        'repos_url': 'https://api.github.com/users/Cat-Snake-Industries/repos',
#        'events_url': 'https://api.github.com/users/Cat-Snake-Industries/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Cat-Snake-Industries/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Cat-Snake-Industries/BinaryBond',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond',
#       'forks_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/forks',
#       'keys_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/teams',
#       'hooks_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/events',
#       'assignees_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/tags',
#       'blobs_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/languages',
#       'stargazers_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/subscription',
#       'commits_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/merges',
#       'archive_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/downloads',
#       'issues_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/deployments',
#       'created_at': '2023-06-13T20:45:32Z',
#       'updated_at': '2023-06-14T23:55:41Z',
#       'pushed_at': '2023-06-15T18:21:04Z',
#       'git_url': 'git://github.com/Cat-Snake-Industries/BinaryBond.git',
#       'ssh_url': 'git@github.com:Cat-Snake-Industries/BinaryBond.git',
#       'clone_url': 'https://github.com/Cat-Snake-Industries/BinaryBond.git',
#       'svn_url': 'https://github.com/Cat-Snake-Industries/BinaryBond',
#       'homepage': None,
#       'size': 2187,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'dev'}},
#     'base': {'label': 'Cat-Snake-Industries:dev',
#      'ref': 'dev',
#      'sha': 'be98f6143f1c7828ac758ab89942341190134f9c',
#      'user': {'login': 'Cat-Snake-Industries',
#       'id': 136504448,
#       'node_id': 'O_kgDOCCLkgA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/136504448?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Cat-Snake-Industries',
#       'html_url': 'https://github.com/Cat-Snake-Industries',
#       'followers_url': 'https://api.github.com/users/Cat-Snake-Industries/followers',
#       'following_url': 'https://api.github.com/users/Cat-Snake-Industries/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Cat-Snake-Industries/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Cat-Snake-Industries/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Cat-Snake-Industries/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Cat-Snake-Industries/orgs',
#       'repos_url': 'https://api.github.com/users/Cat-Snake-Industries/repos',
#       'events_url': 'https://api.github.com/users/Cat-Snake-Industries/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Cat-Snake-Industries/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 653321687,
#       'node_id': 'R_kgDOJvDl1w',
#       'name': 'BinaryBond',
#       'full_name': 'Cat-Snake-Industries/BinaryBond',
#       'private': False,
#       'owner': {'login': 'Cat-Snake-Industries',
#        'id': 136504448,
#        'node_id': 'O_kgDOCCLkgA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/136504448?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Cat-Snake-Industries',
#        'html_url': 'https://github.com/Cat-Snake-Industries',
#        'followers_url': 'https://api.github.com/users/Cat-Snake-Industries/followers',
#        'following_url': 'https://api.github.com/users/Cat-Snake-Industries/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Cat-Snake-Industries/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Cat-Snake-Industries/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Cat-Snake-Industries/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Cat-Snake-Industries/orgs',
#        'repos_url': 'https://api.github.com/users/Cat-Snake-Industries/repos',
#        'events_url': 'https://api.github.com/users/Cat-Snake-Industries/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Cat-Snake-Industries/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Cat-Snake-Industries/BinaryBond',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond',
#       'forks_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/forks',
#       'keys_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/teams',
#       'hooks_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/events',
#       'assignees_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/tags',
#       'blobs_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/languages',
#       'stargazers_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/subscription',
#       'commits_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/merges',
#       'archive_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/downloads',
#       'issues_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/deployments',
#       'created_at': '2023-06-13T20:45:32Z',
#       'updated_at': '2023-06-14T23:55:41Z',
#       'pushed_at': '2023-06-15T18:21:04Z',
#       'git_url': 'git://github.com/Cat-Snake-Industries/BinaryBond.git',
#       'ssh_url': 'git@github.com:Cat-Snake-Industries/BinaryBond.git',
#       'clone_url': 'https://github.com/Cat-Snake-Industries/BinaryBond.git',
#       'svn_url': 'https://github.com/Cat-Snake-Industries/BinaryBond',
#       'homepage': None,
#       'size': 2187,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'dev'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls/4'},
#      'html': {'href': 'https://github.com/Cat-Snake-Industries/BinaryBond/pull/4'},
#      'issue': {'href': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/issues/4'},
#      'comments': {'href': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/issues/4/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls/4/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/pulls/4/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Cat-Snake-Industries/BinaryBond/statuses/591c4668b002ed536a9fc545f6099ea9bdd065c2'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-06-15T18:21:23Z',
#   'org': {'id': 136504448,
#    'login': 'Cat-Snake-Industries',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Cat-Snake-Industries',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136504448?'}},
#  {'id': '29788738802',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 345849201,
#    'name': 'wxpsjhhd/GitHub520',
#    'url': 'https://api.github.com/repos/wxpsjhhd/GitHub520'},
#   'payload': {'repository_id': 345849201,
#    'push_id': 13999731855,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'eb4fabc984284b05bafaa324a4c113f38c57f4c4',
#    'before': '4e2a223e178d13ab2b3cb5ccd70753a7c71475c7',
#    'commits': [{'sha': 'eb4fabc984284b05bafaa324a4c113f38c57f4c4',
#      'author': {'email': 'sunxuebangong@gmail.com', 'name': 'action_bot'},
#      'message': 'update readme content',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wxpsjhhd/GitHub520/commits/eb4fabc984284b05bafaa324a4c113f38c57f4c4'}]},
#   'public': True,
#   'created_at': '2023-06-15T18:21:23Z'},
#  {'id': '29788739141',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 47864957,
#    'login': 'matthiasrsl',
#    'display_login': 'matthiasrsl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/matthiasrsl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47864957?'},
#   'repo': {'id': 649639108,
#    'name': 'matthias-roussel-soyhuce/github-workflow-test',
#    'url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test'},
#   'payload': {'action': 'closed',
#    'number': 26,
#    'pull_request': {'url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/pulls/26',
#     'id': 1394574498,
#     'node_id': 'PR_kwDOJri0xM5TH4Si',
#     'html_url': 'https://github.com/matthias-roussel-soyhuce/github-workflow-test/pull/26',
#     'diff_url': 'https://github.com/matthias-roussel-soyhuce/github-workflow-test/pull/26.diff',
#     'patch_url': 'https://github.com/matthias-roussel-soyhuce/github-workflow-test/pull/26.patch',
#     'issue_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/issues/26',
#     'number': 26,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Tentative de sabotage',
#     'user': {'login': 'matthiasrsl',
#      'id': 47864957,
#      'node_id': 'MDQ6VXNlcjQ3ODY0OTU3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/47864957?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/matthiasrsl',
#      'html_url': 'https://github.com/matthiasrsl',
#      'followers_url': 'https://api.github.com/users/matthiasrsl/followers',
#      'following_url': 'https://api.github.com/users/matthiasrsl/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/matthiasrsl/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/matthiasrsl/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/matthiasrsl/subscriptions',
#      'organizations_url': 'https://api.github.com/users/matthiasrsl/orgs',
#      'repos_url': 'https://api.github.com/users/matthiasrsl/repos',
#      'events_url': 'https://api.github.com/users/matthiasrsl/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/matthiasrsl/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Le contributeur tente d\'outrepasser les vérifications en changeant la liste des reviewers "administrateurs" et en supprimant le validateur "changeset".',
#     'created_at': '2023-06-15T18:19:59Z',
#     'updated_at': '2023-06-15T18:21:23Z',
#     'closed_at': '2023-06-15T18:21:23Z',
#     'merged_at': None,
#     'merge_commit_sha': '37f0ddd30955e241c02bbe8875ce164aa6f12d96',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'matthias-roussel-soyhuce',
#       'id': 114992604,
#       'node_id': 'U_kgDOBtql3A',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/114992604?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/matthias-roussel-soyhuce',
#       'html_url': 'https://github.com/matthias-roussel-soyhuce',
#       'followers_url': 'https://api.github.com/users/matthias-roussel-soyhuce/followers',
#       'following_url': 'https://api.github.com/users/matthias-roussel-soyhuce/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/matthias-roussel-soyhuce/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/matthias-roussel-soyhuce/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/matthias-roussel-soyhuce/subscriptions',
#       'organizations_url': 'https://api.github.com/users/matthias-roussel-soyhuce/orgs',
#       'repos_url': 'https://api.github.com/users/matthias-roussel-soyhuce/repos',
#       'events_url': 'https://api.github.com/users/matthias-roussel-soyhuce/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/matthias-roussel-soyhuce/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/pulls/26/commits',
#     'review_comments_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/pulls/26/comments',
#     'review_comment_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/issues/26/comments',
#     'statuses_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/statuses/325195ba699ed13aa2e4fff4b3f326bb754cfa22',
#     'head': {'label': 'matthias-roussel-soyhuce:sabotage-attempt',
#      'ref': 'sabotage-attempt',
#      'sha': '325195ba699ed13aa2e4fff4b3f326bb754cfa22',
#      'user': {'login': 'matthias-roussel-soyhuce',
#       'id': 114992604,
#       'node_id': 'U_kgDOBtql3A',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/114992604?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/matthias-roussel-soyhuce',
#       'html_url': 'https://github.com/matthias-roussel-soyhuce',
#       'followers_url': 'https://api.github.com/users/matthias-roussel-soyhuce/followers',
#       'following_url': 'https://api.github.com/users/matthias-roussel-soyhuce/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/matthias-roussel-soyhuce/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/matthias-roussel-soyhuce/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/matthias-roussel-soyhuce/subscriptions',
#       'organizations_url': 'https://api.github.com/users/matthias-roussel-soyhuce/orgs',
#       'repos_url': 'https://api.github.com/users/matthias-roussel-soyhuce/repos',
#       'events_url': 'https://api.github.com/users/matthias-roussel-soyhuce/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/matthias-roussel-soyhuce/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 649639108,
#       'node_id': 'R_kgDOJri0xA',
#       'name': 'github-workflow-test',
#       'full_name': 'matthias-roussel-soyhuce/github-workflow-test',
#       'private': False,
#       'owner': {'login': 'matthias-roussel-soyhuce',
#        'id': 114992604,
#        'node_id': 'U_kgDOBtql3A',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/114992604?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/matthias-roussel-soyhuce',
#        'html_url': 'https://github.com/matthias-roussel-soyhuce',
#        'followers_url': 'https://api.github.com/users/matthias-roussel-soyhuce/followers',
#        'following_url': 'https://api.github.com/users/matthias-roussel-soyhuce/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/matthias-roussel-soyhuce/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/matthias-roussel-soyhuce/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/matthias-roussel-soyhuce/subscriptions',
#        'organizations_url': 'https://api.github.com/users/matthias-roussel-soyhuce/orgs',
#        'repos_url': 'https://api.github.com/users/matthias-roussel-soyhuce/repos',
#        'events_url': 'https://api.github.com/users/matthias-roussel-soyhuce/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/matthias-roussel-soyhuce/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/matthias-roussel-soyhuce/github-workflow-test',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test',
#       'forks_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/forks',
#       'keys_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/teams',
#       'hooks_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/hooks',
#       'issue_events_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/events',
#       'assignees_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/tags',
#       'blobs_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/languages',
#       'stargazers_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/stargazers',
#       'contributors_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/contributors',
#       'subscribers_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/subscribers',
#       'subscription_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/subscription',
#       'commits_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/merges',
#       'archive_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/downloads',
#       'issues_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/deployments',
#       'created_at': '2023-06-05T10:10:36Z',
#       'updated_at': '2023-06-14T09:57:31Z',
#       'pushed_at': '2023-06-15T18:20:00Z',
#       'git_url': 'git://github.com/matthias-roussel-soyhuce/github-workflow-test.git',
#       'ssh_url': 'git@github.com:matthias-roussel-soyhuce/github-workflow-test.git',
#       'clone_url': 'https://github.com/matthias-roussel-soyhuce/github-workflow-test.git',
#       'svn_url': 'https://github.com/matthias-roussel-soyhuce/github-workflow-test',
#       'homepage': None,
#       'size': 38,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'matthias-roussel-soyhuce:main',
#      'ref': 'main',
#      'sha': 'c81e4aed90265bd581bf2b90a57c1d1b8e70aaec',
#      'user': {'login': 'matthias-roussel-soyhuce',
#       'id': 114992604,
#       'node_id': 'U_kgDOBtql3A',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/114992604?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/matthias-roussel-soyhuce',
#       'html_url': 'https://github.com/matthias-roussel-soyhuce',
#       'followers_url': 'https://api.github.com/users/matthias-roussel-soyhuce/followers',
#       'following_url': 'https://api.github.com/users/matthias-roussel-soyhuce/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/matthias-roussel-soyhuce/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/matthias-roussel-soyhuce/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/matthias-roussel-soyhuce/subscriptions',
#       'organizations_url': 'https://api.github.com/users/matthias-roussel-soyhuce/orgs',
#       'repos_url': 'https://api.github.com/users/matthias-roussel-soyhuce/repos',
#       'events_url': 'https://api.github.com/users/matthias-roussel-soyhuce/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/matthias-roussel-soyhuce/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 649639108,
#       'node_id': 'R_kgDOJri0xA',
#       'name': 'github-workflow-test',
#       'full_name': 'matthias-roussel-soyhuce/github-workflow-test',
#       'private': False,
#       'owner': {'login': 'matthias-roussel-soyhuce',
#        'id': 114992604,
#        'node_id': 'U_kgDOBtql3A',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/114992604?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/matthias-roussel-soyhuce',
#        'html_url': 'https://github.com/matthias-roussel-soyhuce',
#        'followers_url': 'https://api.github.com/users/matthias-roussel-soyhuce/followers',
#        'following_url': 'https://api.github.com/users/matthias-roussel-soyhuce/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/matthias-roussel-soyhuce/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/matthias-roussel-soyhuce/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/matthias-roussel-soyhuce/subscriptions',
#        'organizations_url': 'https://api.github.com/users/matthias-roussel-soyhuce/orgs',
#        'repos_url': 'https://api.github.com/users/matthias-roussel-soyhuce/repos',
#        'events_url': 'https://api.github.com/users/matthias-roussel-soyhuce/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/matthias-roussel-soyhuce/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/matthias-roussel-soyhuce/github-workflow-test',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test',
#       'forks_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/forks',
#       'keys_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/teams',
#       'hooks_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/hooks',
#       'issue_events_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/events',
#       'assignees_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/tags',
#       'blobs_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/languages',
#       'stargazers_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/stargazers',
#       'contributors_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/contributors',
#       'subscribers_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/subscribers',
#       'subscription_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/subscription',
#       'commits_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/merges',
#       'archive_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/downloads',
#       'issues_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/deployments',
#       'created_at': '2023-06-05T10:10:36Z',
#       'updated_at': '2023-06-14T09:57:31Z',
#       'pushed_at': '2023-06-15T18:20:00Z',
#       'git_url': 'git://github.com/matthias-roussel-soyhuce/github-workflow-test.git',
#       'ssh_url': 'git@github.com:matthias-roussel-soyhuce/github-workflow-test.git',
#       'clone_url': 'https://github.com/matthias-roussel-soyhuce/github-workflow-test.git',
#       'svn_url': 'https://github.com/matthias-roussel-soyhuce/github-workflow-test',
#       'homepage': None,
#       'size': 38,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/pulls/26'},
#      'html': {'href': 'https://github.com/matthias-roussel-soyhuce/github-workflow-test/pull/26'},
#      'issue': {'href': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/issues/26'},
#      'comments': {'href': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/issues/26/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/pulls/26/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/pulls/26/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/matthias-roussel-soyhuce/github-workflow-test/statuses/325195ba699ed13aa2e4fff4b3f326bb754cfa22'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': False,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 2,
#     'deletions': 4,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2023-06-15T18:21:24Z'},
#  {'id': '29788739177',
#   'type': 'DeleteEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 462825006,
#    'name': 'GetTerminus/terraform-pr-commenter',
#    'url': 'https://api.github.com/repos/GetTerminus/terraform-pr-commenter'},
#   'payload': {'ref': 'v2-beta', 'ref_type': 'tag', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-06-15T18:21:24Z',
#   'org': {'id': 7110846,
#    'login': 'GetTerminus',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/GetTerminus',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7110846?'}},
#  {'id': '29788739112',
#   'type': 'PushEvent',
#   'actor': {'id': 59576612,
#    'login': 'Aleksa-Rahachevich',
#    'display_login': 'Aleksa-Rahachevich',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aleksa-Rahachevich',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59576612?'},
#   'repo': {'id': 646914744,
#    'name': 'JakubS01/remote_car_frontend',
#    'url': 'https://api.github.com/repos/JakubS01/remote_car_frontend'},
# ...
#   'public': True,
#   'created_at': '2023-06-15T18:21:23Z',
#   'org': {'id': 12104975,
#    'login': 'CDCgov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CDCgov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12104975?'}},
#  {'id': '29788738704',
#   'type': 'PushEvent',
#   'actor': {'id': 104726049,
#    'login': 'bolone-sengkuni',
#    'display_login': 'bolone-sengkuni',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bolone-sengkuni',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104726049?'},
#   'repo': {'id': 649084850,
#    'name': 'bolone-sengkuni/backup_tandon',
#    'url': 'https://api.github.com/repos/bolone-sengkuni/backup_tandon'},
#   'payload': {'repository_id': 649084850,
#    'push_id': 13999731818,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ba9815538db9de7a2058a3554a8b222d058ccd01',
#    'before': 'a06635fec50a7ad9129cb23dcf4c6e1f7bd24e40',
#    'commits': [{'sha': 'ba9815538db9de7a2058a3554a8b222d058ccd01',
#      'author': {'email': 'toyib30071999@gmail.com', 'name': 'bolone-sengkuni'},
#      'message': 'p',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bolone-sengkuni/backup_tandon/commits/ba9815538db9de7a2058a3554a8b222d058ccd01'}]},
#   'public': True,
#   'created_at': '2023-06-15T18:21:23Z'},
#  {'id': '29788739073',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 540292228,
#    'name': 'MT-Black/MT-Black',
#    'url': 'https://api.github.com/repos/MT-Black/MT-Black'},
#   'payload': {'repository_id': 540292228,
#    'push_id': 13999731747,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'be5c6e2460e5bc3010c421e5b7ca9e20592af979',
#    'before': 'fbfd3d21faf100981e4702cd3fa4e1c1374f7710',
#    'commits': [{'sha': 'be5c6e2460e5bc3010c421e5b7ca9e20592af979',
#      'author': {'email': '3300652636@qq.com', 'name': 'mt-black'},
#      'message': 'generated',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MT-Black/MT-Black/commits/be5c6e2460e5bc3010c421e5b7ca9e20592af979'}]},
#   'public': True,
#   'created_at': '2023-06-15T18:21:24Z'},
#  {'id': '29788738740',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 335414642,
#    'name': 'MKoding/mkoding',
#    'url': 'https://api.github.com/repos/MKoding/mkoding'},
#   'payload': {'repository_id': 335414642,
#    'push_id': 13999731853,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': 'd1134f66c7c74c8f7c56f710c4a7dd15f3b1e255',
#    'before': '9c8e19ec13ad2e993c9901b765e98fe3135bbb66',
#    'commits': [{'sha': 'd1134f66c7c74c8f7c56f710c4a7dd15f3b1e255',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MKoding/mkoding/commits/d1134f66c7c74c8f7c56f710c4a7dd15f3b1e255'}]},
#   'public': True,
#   'created_at': '2023-06-15T18:21:23Z'},
#  {'id': '29788739016',
#   'type': 'PushEvent',
#   'actor': {'id': 136399247,
#    'login': 'sbravehk',
#    'display_login': 'sbravehk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sbravehk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136399247?'},
#   'repo': {'id': 654255352,
#    'name': 'sbravehk/test_pub',
#    'url': 'https://api.github.com/repos/sbravehk/test_pub'},
#   'payload': {'repository_id': 654255352,
#    'push_id': 13999731942,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aa4a37ae7079fa16f3ed0f2f1e4acbaa09c4834a',
#    'before': '410aefa00ae1b5d3c1fc1500cdba2e3c30dcbc96',
#    'commits': [{'sha': 'aa4a37ae7079fa16f3ed0f2f1e4acbaa09c4834a',
#      'author': {'email': 'SmartBraveCoder@gmail.com', 'name': 'smart'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sbravehk/test_pub/commits/aa4a37ae7079fa16f3ed0f2f1e4acbaa09c4834a'}]},
#   'public': True,
#   'created_at': '2023-06-15T18:21:24Z'},
#  {'id': '29788738402',
#   'type': 'PushEvent',
#   'actor': {'id': 46458331,
#    'login': 'SkullNBones12',
#    'display_login': 'SkullNBones12',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SkullNBones12',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46458331?'},
#   'repo': {'id': 588308171,
#    'name': 'SkullNBones12/Small-Scripts',
#    'url': 'https://api.github.com/repos/SkullNBones12/Small-Scripts'},
#   'payload': {'repository_id': 588308171,
#    'push_id': 13999731687,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3f897f7dbda396cc2550fe62786ac411cc6ed97d',
#    'before': '712b52c60b1cb6fd45d57cdee39f64533a4b4c1a',
#    'commits': [{'sha': '3f897f7dbda396cc2550fe62786ac411cc6ed97d',
#      'author': {'email': '46458331+SkullNBones12@users.noreply.github.com',
#       'name': 'SkullNBones12'},
#      'message': 'Rename collatz.py to collatz.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SkullNBones12/Small-Scripts/commits/3f897f7dbda396cc2550fe62786ac411cc6ed97d'}]},
#   'public': True,
#   'created_at': '2023-06-15T18:21:22Z'},
#  {'id': '29788739107',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 9877150,
#    'login': 'Technetium1',
#    'display_login': 'Technetium1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Technetium1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9877150?'},
#   'repo': {'id': 279094308,
#    'name': 'chaotic-aur/packages',
#    'url': 'https://api.github.com/repos/chaotic-aur/packages'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/chaotic-aur/packages/issues/2534',
#     'repository_url': 'https://api.github.com/repos/chaotic-aur/packages',
#     'labels_url': 'https://api.github.com/repos/chaotic-aur/packages/issues/2534/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/chaotic-aur/packages/issues/2534/comments',
#     'events_url': 'https://api.github.com/repos/chaotic-aur/packages/issues/2534/events',
#     'html_url': 'https://github.com/chaotic-aur/packages/issues/2534',
#     'id': 1741539568,
#     'node_id': 'I_kwDOEKKkJM5nzcjw',
#     'number': 2534,
#     'title': '[Request] waybar-hyprland',
#     'user': {'login': 'D3vil0p3r',
#      'id': 83867734,
#      'node_id': 'MDQ6VXNlcjgzODY3NzM0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/83867734?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/D3vil0p3r',
#      'html_url': 'https://github.com/D3vil0p3r',
#      'followers_url': 'https://api.github.com/users/D3vil0p3r/followers',
#      'following_url': 'https://api.github.com/users/D3vil0p3r/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/D3vil0p3r/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/D3vil0p3r/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/D3vil0p3r/subscriptions',
#      'organizations_url': 'https://api.github.com/users/D3vil0p3r/orgs',
#      'repos_url': 'https://api.github.com/users/D3vil0p3r/repos',
#      'events_url': 'https://api.github.com/users/D3vil0p3r/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/D3vil0p3r/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 2213640567,
#       'node_id': 'MDU6TGFiZWwyMjEzNjQwNTY3',
#       'url': 'https://api.github.com/repos/chaotic-aur/packages/labels/request:new-pkg',
#       'name': 'request:new-pkg',
#       'color': 'ffb2fc',
#       'default': False,
#       'description': 'New package requested.'},
#      {'id': 2213747589,
#       'node_id': 'MDU6TGFiZWwyMjEzNzQ3NTg5',
#       'url': 'https://api.github.com/repos/chaotic-aur/packages/labels/waiting:upstream-fix',
#       'name': 'waiting:upstream-fix',
#       'color': '89b2d6',
#       'default': False,
#       'description': 'Waiting for fix in AUR or in the project iself.'},
#      {'id': 3243607367,
#       'node_id': 'MDU6TGFiZWwzMjQzNjA3MzY3',
#       'url': 'https://api.github.com/repos/chaotic-aur/packages/labels/priority:low',
#       'name': 'priority:low',
#       'color': '3C2E51',
#       'default': False,
#       'description': 'This package affects just a few users.'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 6,
#     'created_at': '2023-06-05T11:06:00Z',
#     'updated_at': '2023-06-15T18:21:24Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '### Requested Package:\r\n\r\n[waybar-hyprland](https://aur.archlinux.org/packages/waybar-hyprland)\r\n\r\n### Purpose and Use?\r\n\r\nHighly customizable Wayland bar for Sway and Wlroots based compositors, with workspaces support for Hyprland. Very useful for Hyprland users.\r\n\r\n### Benefits?\r\n\r\n_No response_\r\n\r\n### Builds in clean chroot?\r\n\r\n_No response_\r\n\r\n### Copyright License?\r\n\r\nMIT\r\n\r\n### Expected interest\r\n\r\nMany.\r\n\r\n### Prior availability?\r\n\r\nNo\r\n\r\n### Is this request unique?\r\n\r\nYes\r\n\r\n### Is the package banned?\r\n\r\nNo\r\n\r\n### More information\r\n\r\n_No response_',
#     'reactions': {'url': 'https://api.github.com/repos/chaotic-aur/packages/issues/2534/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/chaotic-aur/packages/issues/2534/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'reopened'},
#    'comment': {'url': 'https://api.github.com/repos/chaotic-aur/packages/issues/comments/1593533391',
#     'html_url': 'https://github.com/chaotic-aur/packages/issues/2534#issuecomment-1593533391',
#     'issue_url': 'https://api.github.com/repos/chaotic-aur/packages/issues/2534',
#     'id': 1593533391,
#     'node_id': 'IC_kwDOEKKkJM5e-2PP',
#     'user': {'login': 'Technetium1',
#      'id': 9877150,
#      'node_id': 'MDQ6VXNlcjk4NzcxNTA=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9877150?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Technetium1',
#      'html_url': 'https://github.com/Technetium1',
#      'followers_url': 'https://api.github.com/users/Technetium1/followers',
#      'following_url': 'https://api.github.com/users/Technetium1/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Technetium1/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Technetium1/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Technetium1/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Technetium1/orgs',
#      'repos_url': 'https://api.github.com/users/Technetium1/repos',
#      'events_url': 'https://api.github.com/users/Technetium1/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Technetium1/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-06-15T18:21:24Z',
#     'updated_at': '2023-06-15T18:21:24Z',
#     'author_association': 'MEMBER',
#     'body': "No problem! It's always fine to ask for clarification :)",
#     'reactions': {'url': 'https://api.github.com/repos/chaotic-aur/packages/issues/comments/1593533391/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-06-15T18:21:24Z',
#   'org': {'id': 66071775,
#    'login': 'chaotic-aur',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/chaotic-aur',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66071775?'}},
#  {'id': '29788739049',
#   'type': 'PushEvent',
#   'actor': {'id': 46377366,
#    'login': 'ExtremelySunnyYK',
#    'display_login': 'ExtremelySunnyYK',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ExtremelySunnyYK',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46377366?'},
#   'repo': {'id': 399216773,
#    'name': 'smartcontractkit/chainlink-solana',
#    'url': 'https://api.github.com/repos/smartcontractkit/chainlink-solana'},
#   'payload': {'repository_id': 399216773,
#    'push_id': 13999731973,
#    'size': 5,
#    'distinct_size': 5,
#    'ref': 'refs/heads/BCI-887-Solana-HeadTracker',
#    'head': '7fd9084bd3c979cdaa7011be7f6aaae9f1c143a5',
#    'before': '4ee8456144a97eafea8f9ca34ef965439de0b2fc',
#    'commits': [{'sha': '23a5366a6131ecfaed97d9715b26ae670f6235e5',
#      'author': {'email': 'chiayongkang@hotmail.com', 'name': 'Yong Kang'},
#      'message': 'Added subscription and client interfaces',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/smartcontractkit/chainlink-solana/commits/23a5366a6131ecfaed97d9715b26ae670f6235e5'},
#     {'sha': '2da21a2dca614e6492ad8d062293239590ec9b79',
#      'author': {'email': 'chiayongkang@hotmail.com', 'name': 'Yong Kang'},
#      'message': 'Updated config to include polling interval',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/smartcontractkit/chainlink-solana/commits/2da21a2dca614e6492ad8d062293239590ec9b79'},
#     {'sha': 'ed7192a226fd601433d69d7e6a8af5ec2b31b334',
#      'author': {'email': 'chiayongkang@hotmail.com', 'name': 'Yong Kang'},
#      'message': 'removed HeadByHash from client interface - not needed',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/smartcontractkit/chainlink-solana/commits/ed7192a226fd601433d69d7e6a8af5ec2b31b334'},
#     {'sha': 'fc2586e66fb8ba8f4153ef38aa698602c4b9f38b',
#      'author': {'email': 'chiayongkang@hotmail.com', 'name': 'Yong Kang'},
#      'message': 'Added subscription concrete type + tests',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/smartcontractkit/chainlink-solana/commits/fc2586e66fb8ba8f4153ef38aa698602c4b9f38b'},
#     {'sha': '7fd9084bd3c979cdaa7011be7f6aaae9f1c143a5',
#      'author': {'email': 'chiayongkang@hotmail.com', 'name': 'Yong Kang'},
#      'message': 'Updated helper for client',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/smartcontractkit/chainlink-solana/commits/7fd9084bd3c979cdaa7011be7f6aaae9f1c143a5'}]},
#   'public': True,
#   'created_at': '2023-06-15T18:21:24Z',
#   'org': {'id': 25111032,
#    'login': 'smartcontractkit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/smartcontractkit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25111032?'}},
#  {'id': '29788738382',
#   'type': 'PushEvent',
#   'actor': {'id': 80115849,
#    'login': 'YordiHernandez',
#    'display_login': 'YordiHernandez',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/YordiHernandez',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80115849?'},
#   'repo': {'id': 651128856,
#    'name': 'Joshua53Barrios/ReactCertificados',
#    'url': 'https://api.github.com/repos/Joshua53Barrios/ReactCertificados'},
#   'payload': {'repository_id': 651128856,
#    'push_id': 13999731694,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/yordi',
#    'head': '79454b810ce1a210f95fa1c0f1dd719234be30c5',
#    'before': 'ce8d62e02b2c172599521aa1abd7289c4945a77b',
#    'commits': [{'sha': '79454b810ce1a210f95fa1c0f1dd719234be30c5',
#      'author': {'email': 'superyo234@gmail.com', 'name': 'Yordi'},
#      'message': 'Peticion post y put con fetch funcionando',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Joshua53Barrios/ReactCertificados/commits/79454b810ce1a210f95fa1c0f1dd719234be30c5'}]},
#   'public': True,
#   'created_at': '2023-06-15T18:21:22Z'}]

# %%
# HTTP POST METHOD

r = requests.post('https://httpbin.org/post', data={'key': 'value'})

# %%
r = requests.put('https://httpbin.org/put', data={'key': 'value'})
r = requests.delete('https://httpbin.org/delete')
r = requests.head('https://httpbin.org/get')
r = requests.options('https://httpbin.org/get')

# %%
# passing payload to url

payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)

print(r.url)
#https://httpbin.org/get?key2=value2&key1=value1
# Out:
# https://httpbin.org/get?key1=value1&key2=value2
